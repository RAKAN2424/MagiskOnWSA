# %% [markdown]
# <a href="https://colab.research.google.com/github/RAKAN2424/MagiskOnWSA/blob/main-1/notebooks/google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rsxdalv/tts-generation-webui

import os
os.chdir("./tts-generation-webui")
# Out:
# Cloning into 'tts-generation-webui'...
# remote: Enumerating objects: 3486, done.
# remote: Counting objects: 100% (1180/1180), done.
# remote: Compressing objects: 100% (621/621), done.
# remote: Total 3486 (delta 714), reused 715 (delta 523), pack-reused 2306 (from 1)
# Receiving objects: 100% (3486/3486), 33.16 MiB | 29.76 MiB/s, done.
# Resolving deltas: 100% (1960/1960), done.

# %%
# Adapted from Dockerfile
# Install python dependencies
# !uv pip install --no-progress --system --upgrade pip==23.3.2 setuptools
# !uv pip install --no-progress --system torch==2.3.1 torchvision torchaudio
# !pip install uv
# !uv pip install --no-progress --system -r requirements.txt
# !uv pip install --no-progress --system -r requirements_bark_hubert_quantizer.txt
# !uv pip install --no-progress --system -r requirements_rvc.txt
# !uv pip install --no-progress --system -r requirements_audiocraft.txt
# !uv pip install --no-progress --system -r requirements_styletts2.txt
# !uv pip install --no-progress --system -r requirements_vall_e.txt
# !uv pip install --no-progress --system -r requirements_maha_tts.txt
# !uv pip install --no-progress --system -r requirements_stable_audio.txt
# !pip install --no-progress --system -r requirements_stable_audio.txt
# !uv pip install --no-progress --system hydra-core==1.3.2
# !uv pip install --no-progress --system nvidia-ml-py
# !uv pip install --no-progress --system soundfile==0.12.1
# !uv pip install --no-progress --system huggingface_hub==0.25.2


# Get latest Node.js
# !wget https://nodejs.org/dist/v22.9.0/node-v22.9.0-linux-x64.tar.gz
# !tar xfz node-v22.9.0-linux-x64.tar.gz
# !cp -r node-v22.9.0-linux-x64/* /usr/local/

# # Build the React UI
# !cd react-ui && npm install && npm run build
# Out:
# Requirement already satisfied: uv in /usr/local/lib/python3.10/dist-packages (0.5.7)
# Using Python 3.10.12 environment at: /usr
# Audited 15 packages in 138ms
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 112ms
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 100ms
# Using Python 3.10.12 environment at: /usr
# Audited 2 packages in 121ms
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 106ms
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 95ms
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 107ms
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --no-progress
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 101ms
# Using Python 3.10.12 environment at: /usr
# Audited 1 package in 85ms

# %%
# Start the App
# !python server.py --share
# Note - Node.js/React UI works but isn't accesssible by default on Google Colab, only gradio is easy to open.
# Out:
# Starting server...
#
# Env file not found. Creating default env.
# Config file not found. Creating default config.
# Loading decorator extension Decorator Save Ogg
#   Skipping disabled decorator extension decorator_disabled
#   Decorator decorator_save_flac loaded
#   Decorator decorator_save_flac_generator loaded
#   Decorator decorator_save_ogg loaded
#   Decorator decorator_save_ogg_generator loaded
#   Done in 0.02 seconds. (Decorator Save Ogg)
#
# Loading decorator extension Decorator Save Waveform
#   Decorator decorator_save_waveform_plot loaded
#   Done in 0.78 seconds. (Decorator Save Waveform)
#
# Loading decorator extension Decorator Average Execution Time
#   Decorator decorator_average_execution_time loaded
#   Done in 0.00 seconds. (Decorator Average Execution Time)
#
# Starting React UI...
# Starting Postgres...
# Gradio share mode enabled
# Starting Gradio server...
#  Gradio interface options:
#   inline:               False
#   inbrowser:            True
#   share:                True
#   debug:                False
#   max_threads:          40
#   auth:                 None
#   auth_message:         None
#   prevent_thread_lock:  False
#   show_error:           False
#   server_name:          127.0.0.1
#   server_port:          7770
#   height:               500
#   width:                100%
#   favicon_path:         None
#   ssl_keyfile:          None
#   ssl_certfile:         None
#   ssl_keyfile_password: None
#   ssl_verify:           True
#   quiet:                True
#   show_api:             True
#   _frontend:            True
# /bin/sh: 1: postgres: not found
# Loading Bark TTS tab...
#
# > tts-generation-webui-react@0.1.0 start
# > next start
#
# sh: 1: next: not found
# ⠙  Done in 7.27 seconds. (Bark TTS)
#
# Loading Bark Voice Clone tab...
#   Done in 0.01 seconds. (Bark Voice Clone)
#
# Loading Tortoise TTS tab...
#   Done in 0.04 seconds. (Tortoise TTS)
#
# Loading SeamlessM4Tv2Model tab...
#   Done in 0.02 seconds. (SeamlessM4Tv2Model)
#
# Loading Valle-X tab...
#   Done in 0.01 seconds. (Valle-X)
#
# Loading MMS tab...
#   Done in 0.09 seconds. (MMS)
#
# Loading MahaTTS tab...
# /usr/local/lib/python3.10/dist-packages/gradio/components/dropdown.py:226: UserWarning: The value passed into gr.Dropdown() is not in the list of choices. Please update the list of choices to include: None or set allow_custom_value=True.
#   warnings.warn(
#   Done in 0.01 seconds. (MahaTTS)
#
# Loading StyleTTS2 tab...
#   Done in 0.01 seconds. (StyleTTS2)
#
# Loading Bark Legacy Extension...
#   Done in 0.10 seconds. (Bark Legacy Extension)
#
# Loading XTTS-Simple Extension...
# Failed to load XTTS-Simple Extension tab. Please check your configuration.
# Error:
# Stacktrace: Traceback (most recent call last):
#   File "/content/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts_webui/extensions_loader/interface_extensions.py", line 50, in _handle_package
#     main_tab()
#   File "/usr/local/lib/python3.10/dist-packages/extension_xtts_simple/main.py", line 24, in extension__tts_generation_webui
#     main_ui()
#   File "/usr/local/lib/python3.10/dist-packages/extension_xtts_simple/main.py", line 140, in main_ui
#     model_name = model_select_ui(
#   File "/content/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts_webui/utils/list_dir_models.py", line 28, in model_select_ui
#     models = get_models(repos, abs_dir)
#   File "/content/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts_webui/utils/list_dir_models.py", line 19, in get_models
#     return repos + [(x, os.path.join(abs_dir, x)) for x in list_dir_models(abs_dir)]
#   File "/content/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts-generation-webui/tts_webui/utils/list_dir_models.py", line 12, in list_dir_models
#     return [x for x in next(os.walk(abs_dir))[1] if x not in ["cache"]]
# StopIteration
#
#   Done in 0.02 seconds. (XTTS-Simple Extension)
#
# Loading Parler-TTS Extension...
#   Done in 0.84 seconds. (Parler-TTS Extension)
#
# Loading F5-TTS Extension...
# 2024-12-11 15:33:23.967667: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-11 15:33:24.036976: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-11 15:33:24.054552: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-11 15:33:24.125166: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-11 15:33:26.315857: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/vocos/pretrained.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location="cpu")
# Download Vocos from huggingface charactr/vocos-mel-24khz
#   Done in 16.43 seconds. (F5-TTS Extension)
#
# Loading MARS5 Extension...
#   Done in 0.03 seconds. (MARS5 Extension)
#
# Loading Stable Audio tab...
#   Done in 0.04 seconds. (Stable Audio)
#
# Loading MAGNeT tab...
#   Done in 0.02 seconds. (MAGNeT)
#
# Loading MusicGen tab...
#   Done in 0.02 seconds. (MusicGen)
#
# Loading AudioCraft Plus Extension...
# False
# /usr/local/lib/python3.10/dist-packages/gradio/components/dropdown.py:226: UserWarning: The value passed into gr.Dropdown() is not in the list of choices. Please update the list of choices to include: No models found or set allow_custom_value=True.
#   warnings.warn(
#   Done in 0.14 seconds. (AudioCraft Plus Extension)
#
# Loading Riffusion Extension...
#   Done in 0.02 seconds. (Riffusion Extension)
#
# Loading MusicGen (Mac) Extension...
#   Done in 0.02 seconds. (MusicGen (Mac) Extension)
#
# Loading RVC tab...
#   Done in 0.02 seconds. (RVC)
#
# Loading UVR5 tab...
#   Done in 0.01 seconds. (UVR5)
#
# Loading Demucs tab...
#   Done in 0.01 seconds. (Demucs)
#
# Loading Vocos tab...
#   Done in 0.01 seconds. (Vocos)
#
# Loading Audio Separator Extension...
#   Done in 0.09 seconds. (Audio Separator Extension)
#
# Loading Resemble Enhance Extension...
#   Done in 0.01 seconds. (Resemble Enhance Extension)
#
# Loading Gallery History Extension...
#   Done in 0.02 seconds. (Gallery History Extension)
#
# Loading FFMPEG Metadata Extension...
#   Done in 0.00 seconds. (FFMPEG Metadata Extension)
#
# Loading Simple Remixer Extension...
#   Done in 0.02 seconds. (Simple Remixer Extension)
#
# Loading Whisper Extension...
#   Done in 0.01 seconds. (Whisper Extension)
#
# Loading XTTS Fine-tuning Demo Extension...
#   Done in 9.98 seconds. (XTTS Fine-tuning Demo Extension)
#
# Loading Huggingface Cache Manager Extension...
#   Done in 0.01 seconds. (Huggingface Cache Manager Extension)
#
# Loading Model Downloader Extension...
#   Done in 0.00 seconds. (Model Downloader Extension)
#
# Loading Model Location Settings tab...
#   Done in 0.01 seconds. (Model Location Settings)
#
# Loading GPU Info tab...
#   Done in 0.00 seconds. (GPU Info)
#
# Loading Installed Packages tab...
#   Done in 0.00 seconds. (Installed Packages)
#
#
#
#
# 2024-12-11 15:33:45,681 [INFO] HTTP Request: GET http://127.0.0.1:7770/gradio_api/startup-events "HTTP/1.1 200 OK"
# 2024-12-11 15:33:46,364 [INFO] HTTP Request: HEAD http://127.0.0.1:7770/ "HTTP/1.1 200 OK"
# 2024-12-11 15:33:46,503 [INFO] HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# * Running on public URL: https://3da9212e503a8a3905.gradio.live

# %%
# (Optional) Fix for deepspeed for tortoise
# uv pip uninstall deepspeed
# uv pip install deepspeed==0.8.3
